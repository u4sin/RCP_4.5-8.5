# %%
import numpy as np
import pandas as pd
import glob
from matplotlib import pyplot as plt
from pathlib import Path
import scipy.stats as st
import math as m
import seaborn as sns
from pylab import *
from matplotlib import rc, rcParams

# %%
folder="/home/nishu/my_projects/NMP/22_08_22/Future_Projection_Himlaya_2_8_2022/rawdata_422672_EH85/monthly_1850_2005"

# %%
sum=np.zeros((40,2))
count=0
mean_anomaly=0
figure, ax=plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})
for file in Path(folder).glob('*.txt'):
    df = pd.read_csv(file)
    mean_anomaly+=df['ppanmly']/40
    count+=1
#     print(df)
    
    ax[0].tick_params(labeltop=False, labelright=True)
    ax[0].margins(0)
    ax[0].plot(df["year"],df["ppanmly"],color='gray', linewidth=0.1)
    ax[0].axhline(y=0, color='blue', linestyle='dotted', linewidth='1')
ax[0].plot(df['year'],mean_anomaly, color='black',label='Historical')  
ax[0].set_ylabel("mm/day", weight='bold')
print('count=',count)  

# activate latex text rendering

rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']    


folder1="/home/nishu/my_projects/NMP/22_08_22/Future_Projection_Himlaya_2_8_2022/rawdata_422672_EH85/monthly_2006_2100"
sum1=np.zeros((43,2))
count1=0
mean_anomaly1=0

for file in Path(folder1).glob('*.txt'):
    df1 = pd.read_csv(file)
#     print(df1)
    mean_anomaly1+=df1['ppanmly']/40
    count1+=1
    #print(df1)
    ax[0].tick_params(labeltop=False, labelright=True)
    ax[0].margins(0)
    ax[0].plot(df1['year'], df1['ppanmly'],color='coral', linewidth=0.1)
    ax[0].axhline(y=0, color='blue', linestyle='dotted', linewidth='1')

ax[0].plot(df1['year'],mean_anomaly1, color='orangered', label='RCP8.5')  
ax[0].legend()
# ax[0]=plt.figure(figsize=(6,3))
# ax[1]=plt.figure(figsize=(1,3))
ax[1]=plt.boxplot(mean_anomaly1)
print('count1=',count)  


plt.show()
# Out:
# count= 40
# count1= 40
# <ipython-input-3-a0946b2730e5>:21: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']

# %%
mean_anomaly1.mean()
# Out:
# 0.9709927907226313

# %%
# font size etc.
VERY_SMALL_SIZE = 5
SMALL_SIZE = 8
MEDIUM_SIZE = 12
BIGGER_SIZE = 16

# plt.rc('font', weight='bold')
plt.rc('font', size=SMALL_SIZE, weight='bold')          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=VERY_SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title


folder1="/home/nishu/my_projects/NMP/22_08_22/Future_Projection_Himlaya_2_8_2022/rawdata_422672_EH85/monthly_2006_2100"
fig, ax2=plt.subplots()
data=np.zeros((95,40))
count2=0
model=[]
for file in Path(folder1).glob('*.txt'):
    df1 = pd.read_csv(file)
#     print(df1)
 
    for i in range(len(df1['ppanmly'])):
        data[i,count2]=df1['ppanmly'][i]
    mean_anomaly1+=df1['ppanmly']/40
    count2+=1
    #print(df1)
    #ax2.tick_params(labeltop=False, labelright=True)
    #ax2.margins(0)
    #plt.plot(df1['Year'], df1['ppanmly'],color='orange', linewidth=0.1)
    ax2.axhline(y=0, color='blue', linestyle='dotted', linewidth='1')
    mname=str(file)
#     print(mname)
    start=mname[:123]
    #print(start)
    end=mname[:len(mname)-66]
    if start in end:
        model_name=end.replace(start,'')
        model.append(model_name)
    print(model)
#     ax2.rc('font', weight='bold')
    ax2.set_xticklabels(model)
    plt.xticks(rotation=90)
ax2.set_ylabel('Anomaly (mm/day)', weight='bold')
# ax2.set_xlabel('Models', weight='bold')
ax2.boxplot(data)
#ax[0].plot(df1['Year'],mean_anomaly1, color='red', label='RCP4.5')  
#ax[0].legend()
# ax[0]=plt.figure(figsize=(6,3))
# ax[1]=plt.figure(figsize=(1,3))

print('count1=',count)  


plt.show()
# Out:
# ['ACCESS1-0']
# ['ACCESS1-0', 'ACCESS1-3']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MPI-ESM-LR']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MPI-ESM-LR', 'MPI-ESM-MR']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MPI-ESM-LR', 'MPI-ESM-MR', 'MRI-CGCM3']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MPI-ESM-LR', 'MPI-ESM-MR', 'MRI-CGCM3', 'NorESM1-ME']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MPI-ESM-LR', 'MPI-ESM-MR', 'MRI-CGCM3', 'NorESM1-ME', 'NorESM1-M']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MPI-ESM-LR', 'MPI-ESM-MR', 'MRI-CGCM3', 'NorESM1-ME', 'NorESM1-M', 'onem']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MPI-ESM-LR', 'MPI-ESM-MR', 'MRI-CGCM3', 'NorESM1-ME', 'NorESM1-M', 'onem', 'bcc-csm1-1']
# ['ACCESS1-0', 'ACCESS1-3', 'BNU-ESM', 'CanESM2', 'CCSM4', 'CESM1-BGC', 'CESM1-CAM5', 'CMCC-CM', 'CMCC-CMS', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'EC-EARTH', 'FIO-ESM', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-H', 'GISS-E2-R', 'GISS-E2-R', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-CC', 'HadGEM2-ES', 'inmcm4', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'IPSL-CM5B-LR', 'MIROC5', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MPI-ESM-LR', 'MPI-ESM-MR', 'MRI-CGCM3', 'NorESM1-ME', 'NorESM1-M', 'onem', 'bcc-csm1-1', 'FGOALS-g2']
# <ipython-input-8-7fed7578daff>:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(model)
# count1= 40
