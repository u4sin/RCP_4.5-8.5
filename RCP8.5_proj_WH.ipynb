# %%
import numpy as np
import pandas as pd
import glob
from matplotlib import pyplot as plt
from pathlib import Path
import scipy.stats as st
import math as m
import seaborn as sns
from pylab import *
from matplotlib import rc, rcParams

# %%
folder="/home/nishu/my_projects/NMP/22_08_22/Future_Projection_Himlaya_2_8_2022/rawdata_299095_WH_8.5/monthly_1986_2005"

# %%
sum=np.zeros((40,2))
count=0
mean_anomaly=0
figure, ax=plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})
for file in Path(folder).glob('*.txt'):
    df = pd.read_csv(file)
    mean_anomaly+=df['ppanmly']/40
    count+=1
#     print(df)
    
    ax[0].tick_params(labeltop=False, labelright=True)
    ax[0].margins(0)
    ax[0].plot(df["year"],df["ppanmly"],color='gray', linewidth=0.1)
    ax[0].axhline(y=0, color='blue', linestyle='dotted', linewidth='1')
ax[0].plot(df['year'],mean_anomaly, color='black',label='Historical')  
ax[0].set_ylabel("mm/day", weight='bold')
print('count=',count)  

# activate latex text rendering

rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']    


folder1="/home/nishu/my_projects/NMP/22_08_22/Future_Projection_Himlaya_2_8_2022/rawdata_299095_WH_8.5/monthly_2006_2100"
sum1=np.zeros((43,2))
count1=0
mean_anomaly1=0

for file in Path(folder1).glob('*.txt'):
    df1 = pd.read_csv(file)
#     print(df1)
    mean_anomaly1+=df1['ppanmly']/40
    count1+=1
    #print(df1)
    ax[0].tick_params(labeltop=False, labelright=True)
    ax[0].margins(0)
    ax[0].plot(df1['year'], df1['ppanmly'],color='coral', linewidth=0.1)
    ax[0].axhline(y=0, color='blue', linestyle='dotted', linewidth='1')

ax[0].plot(df1['year'],mean_anomaly1, color='orangered', label='RCP8.5')  
ax[0].legend()
# ax[0]=plt.figure(figsize=(6,3))
# ax[1]=plt.figure(figsize=(1,3))
ax[1]=plt.boxplot(mean_anomaly1)
print('count1=',count)  


plt.show()
# Out:
# count= 40
# count1= 40
# <ipython-input-3-dfe518e87e60>:21: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']

# %%
mean_anomaly1.mean()
# Out:
# 0.24466083704763156
