# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.projections import PolarAxes
import mpl_toolkits.axisartist.grid_finder as gf
import mpl_toolkits.axisartist.floating_axes as fa


class TaylorDiagram(object):
  def __init__(self, STD ,fig=None, rect=111, label='_'):
    self.STD = STD
    tr = PolarAxes.PolarTransform()
    # Correlation labels
    rlocs = np.concatenate(((np.arange(11.0) / 10.0), [0.95, 0.99]))
    tlocs = np.arccos(rlocs) # Conversion to polar angles
    gl1 = gf.FixedLocator(tlocs) # Positions
    tf1 = gf.DictFormatter(dict(zip(tlocs, map(str, rlocs))))
    # Standard deviation axis extent
    self.smin = 0
    self.smax = 2.4 * self.STD
    gh = fa.GridHelperCurveLinear(tr,extremes=(0,(np.pi/2),self.smin,self.smax),grid_locator1=gl1,tick_formatter1=tf1,)
    if fig is None:
      fig = plt.figure()
    ax = fa.FloatingSubplot(fig, rect, grid_helper=gh)
    fig.add_subplot(ax)
    # Angle axis
    ax.axis['top'].set_axis_direction('bottom')
    ax.axis['top'].label.set_text("Correlation coefficient")
    ax.axis['top'].toggle(ticklabels=True, label=True)
    ax.axis['top'].major_ticklabels.set_axis_direction('top')
    ax.axis['top'].label.set_axis_direction('top')
    # X axis
    ax.axis['left'].set_axis_direction('bottom')
    ax.axis['left'].label.set_text("Standard deviation")
    ax.axis['left'].toggle(ticklabels=True, label=True)
    ax.axis['left'].major_ticklabels.set_axis_direction('bottom')
    ax.axis['left'].label.set_axis_direction('bottom')
    # Y axis
    ax.axis['right'].set_axis_direction('top')
    ax.axis['right'].label.set_text("Standard deviation")
    ax.axis['right'].toggle(ticklabels=True, label=True)
    ax.axis['right'].major_ticklabels.set_axis_direction('left')
    ax.axis['right'].label.set_axis_direction('top')
    # Useless
    ax.axis['bottom'].set_visible(False)
    # Contours along standard deviations
    ax.grid()
    self._ax = ax # Graphical axes
    self.ax = ax.get_aux_axes(tr) # Polar coordinates
    # Add reference point and STD contour
    l , = self.ax.plot([0], self.STD, 'k*', ls='', ms=12, label=label)
    l1 , = self.ax.plot([0], self.STD, 'k*', ls='', ms=12, label=label)
    t = np.linspace(0, (np.pi / 2.0))
    t1 = np.linspace(0, (np.pi / 2.0))
    r = np.zeros_like(t) + self.STD
    r1 = np.zeros_like(t) + self.STD
    self.ax.plot(t, r, 'k--', label='_')
    # Collect sample points for latter use (e.g. legend)
    self.samplePoints = [l]
    self.samplePoints = [l1]
  def add_sample(self,STD,r,*args,**kwargs):
    l,= self.ax.plot(np.arccos(r), STD, *args, **kwargs) # (theta, radius)
    self.samplePoints.append(l)
    return l

  def add_sample(self,STD,r1,*args,**kwargs):
    l1,= self.ax.plot(np.arccos(r1), STD, *args, **kwargs) # (theta, radius)
    self.samplePoints.append(l1)
    return l1

  def add_contours(self,levels=5,**kwargs):
    rs, ts = np.meshgrid(np.linspace(self.smin, self.smax), np.linspace(0, (np.pi / 2.0)))
    RMSE=np.sqrt(np.power(self.STD, 2) + np.power(rs, 2) - (2.0 * self.STD * rs  *np.cos(ts)))
    contours = self.ax.contour(ts, rs, RMSE, levels, **kwargs)
    return contours

def srl(obsSTD, s, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17,s18,s19,s20,s21,s22,s23,s24,s25,s26,s27,s28,s29,s30,s31,s32,s33,s34,s35,s36,s37,s38,s39,s40,s41,s42, r, r1,r2,r3,r4,r5,r6,r7,r8,r9,r10,r11,r12,r13,r14,r15,r16,r17,r18,r19,r20,r21,r22,r23,r24,r25,r26,r27,r28,r29,r30,r31,r32,r33,r34,r35,r36,r37,r38,r39,r40,r41,r42, l,l1,l2,l3,l4,l5,l6,l7,l8,l9,l10,l11,l12,l13,l14,l15,l16,l17,l18,l19,l20,l21,l22,l23,l24,l25,l26,l27,l28,l29,l30,l31,l32,l33,l34,l35,l36,l37,l38,l39,l40,l41,l42, fname):
  fig=plt.figure(figsize=(16,16))
  dia=TaylorDiagram(obsSTD, fig=fig, rect=111, label='ref')
  plt.clabel(dia.add_contours(colors='#808080'), inline=1, fontsize=10)
  srlc = zip(s, r, l)
  srlc1 = zip(s1, r1, l1)
  srlc2 = zip(s2, r2, l2)
  srlc3 = zip(s3, r3, l3)
  srlc4 = zip(s4, r4, l4)
  srlc5 = zip(s5, r5, l5)
  srlc6 = zip(s6, r6, l6)
  srlc7 = zip(s7, r7, l7)
  srlc8 = zip(s8, r8, l8)
  srlc9 = zip(s9, r9, l9)
  srlc10 = zip(s10, r10, l10)
  srlc11 = zip(s11, r11, l11)
  srlc12 = zip(s12, r12, l12)
  srlc13 = zip(s13, r13, l13)
  srlc14 = zip(s14, r14, l14)
  srlc15 = zip(s15, r15, l15)
  srlc16 = zip(s16, r16, l16)
  srlc17 = zip(s17, r17, l17)
  srlc18 = zip(s18, r18, l18)
  srlc19 = zip(s19, r19, l19)
  srlc20 = zip(s20, r20, l20)
  srlc21 = zip(s21, r21, l21)
  srlc22 = zip(s22, r22, l22)
  srlc23 = zip(s23, r23, l23)
  srlc24 = zip(s24, r24, l24)
  srlc25 = zip(s25, r25, l25)
  srlc26 = zip(s26, r26, l26)
  srlc27 = zip(s27, r27, l27)
  srlc28 = zip(s28, r28, l28)
  srlc29 = zip(s29, r29, l29)
  srlc30 = zip(s30, r30, l30)
  srlc31 = zip(s31, r31, l31)
  srlc32 = zip(s32, r32, l32)
  srlc33 = zip(s33, r33, l33)
  srlc34 = zip(s34, r34, l34)
  srlc35 = zip(s35, r35, l35)
  srlc36 = zip(s36, r36, l36)
  srlc37 = zip(s37, r37, l37)
  srlc38 = zip(s38, r38, l38)
  srlc39 = zip(s39, r39, l39)
  srlc40 = zip(s40, r40, l40)
  srlc41 = zip(s41, r41, l41)
  srlc42 = zip(s42, r42, l42)

   
  for i in srlc:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'black', mfc = 'black', mew=1.6)
    
  for i in srlc1:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'dimgrey', mfc = 'dimgrey', mew=1.6)
  for i in srlc2:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'brown', mfc = 'brown', mew=1.6)
  for i in srlc3:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'red', mfc = 'red', mew=1.6)
  for i in srlc4:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'mistyrose', mfc = 'mistyrose', mew=1.6)
  for i in srlc5:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'coral', mfc = 'coral', mew=1.6)
  for i in srlc6:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'chocolate', mfc = 'chocolate', mew=1.6)
  for i in srlc7:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'peru', mfc = 'peru', mew=1.6)
  for i in srlc8:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'tan', mfc = 'tan', mew=1.6)
  for i in srlc9:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'orange', mfc = 'orange', mew=1.6)
  for i in srlc10:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'goldenrod', mfc = 'goldenrod', mew=1.6)
  for i in srlc11:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'gold', mfc = 'gold', mew=1.6)
  for i in srlc12:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'darkkhaki', mfc = 'darkkhaki', mew=1.6)
  for i in srlc13:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'olive', mfc = 'olive', mew=1.6)
  for i in srlc14:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'yellow', mfc = 'yellow', mew=1.6)
  for i in srlc15:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'olivedrab', mfc = 'olivedrab', mew=1.6)
  for i in srlc16:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'yellowgreen', mfc = 'yellowgreen', mew=1.6)
  for i in srlc17:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'darkolivegreen', mfc = 'darkolivegreen', mew=1.6)
  for i in srlc18:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'honeydew', mfc = 'honeydew', mew=1.6)
  for i in srlc19:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'darkseagreen', mfc = 'darkseagreen', mew=1.6)
  for i in srlc20:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'forestgreen', mfc = 'forestgreen', mew=1.6)
  for i in srlc21:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'lightcyan', mfc = 'lightcyan', mew=1.6)
  for i in srlc22:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'teal', mfc = 'teal', mew=1.6)
  for i in srlc23:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'aqua', mfc = 'aqua', mew=1.6)
  for i in srlc24:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'cadetblue', mfc = 'cadetblue', mew=1.6)
  for i in srlc25:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'darkturquoise', mfc = 'darkturquoise', mew=1.6)
  for i in srlc26:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'steelblue', mfc = 'steelblue', mew=1.6)
  for i in srlc27:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'aliceblue', mfc = 'aliceblue', mew=1.6)
  for i in srlc28:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'lightslategrey', mfc = 'lightslategrey', mew=1.6)
  for i in srlc29:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'lightsteelblue', mfc = 'lightsteelblue', mew=1.6)
  for i in srlc30:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'cornflowerblue', mfc = 'cornflowerblue', mew=1.6)
  for i in srlc31:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'ghostwhite', mfc = 'ghostwhite', mew=1.6)
  for i in srlc32:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'lavender', mfc = 'lavender', mew=1.6)
  for i in srlc33:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'midnightblue', mfc = 'midnightblue', mew=1.6)
  for i in srlc34:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'darkblue', mfc = 'darkblue', mew=1.6)
  for i in srlc35:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'slateblue', mfc = 'slateblue', mew=1.6)
  for i in srlc36:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'mediumpurple', mfc = 'mediumpurple', mew=1.6)
  for i in srlc37:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'rebeccapurple', mfc = 'rebeccapurple', mew=1.6)
  for i in srlc38:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'indigo', mfc = 'indigo', mew=1.6)
  for i in srlc39:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'thistle', mfc = 'thistle', mew=1.6)
  for i in srlc40:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'magenta', mfc = 'magenta', mew=1.6)
  for i in srlc41:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'hotpink', mfc = 'hotpink', mew=1.6)
  for i in srlc42:
    dia.add_sample(i[0], i[1], label=i[2], marker='s',mec = 'crimson', mfc = 'crimson', mew=1.6)

#   for i in srlc1:
#     dia.add_sample(i[0], i[1], label=i[2], marker='^', mec = 'blue', mfc = 'none', mew=1.6)
  spl = [p.get_label() for p in dia.samplePoints]
  fig.legend(dia.samplePoints, spl, numpoints=1, prop=dict(size=7.5), loc=[0.75,0])
  plt.show()

obsSTD = 0.9999999999999997

s = [0.866667]
s1 = [0.773953]
s2 = [1.301657]
s3 = [1.103996]
s4 = [2.314304]
s5 = [2.257783]
s6 = [1.678784]
s7 = [1.433488]
s8 = [2.190256]
s9 = [1.334810]
s10 = [1.155752]
s11 = [0.892544]
s12 = [0.600741]
s13 = [0.740658]
s14 = [0.884027]
s15 = [2.203037]
s16 = [0.660578]
s17 = [0.078889]
s18 = [0.081144]
s19 = [0.102641]
s20 = [0.148620]
s21 = [0.133661]
s22 = [0.116218]
s23 = [0.086584]
s24 = [0.202965]
s25 = [1.141302]
s26 = [0.834353]
s27 = [0.883834]
s28 = [0.867486]
s29 = [1.668802]
s30 = [1.157841]
s31 = [0.664441]
s32 = [1.895683]
s33 = [1.336907]
s34 = [1.136925]
s35 = [1.209143]
s36 = [1.301431]
s37 = [0.801538]
s38 = [1.742849]
s39 = [1.924103]
s40 = [0.289742]
s41 = [1.666554]
s42 = [1.402673]


r = [-0.216630]
r1 = [0.328898]
r2 = [-0.166042]
r3 = [-0.117825]
r4 = [0.291297]
r5 = [0.449119]
r6 = [0.171616]
r7 = [0.048490]
r8 = [-0.021874]
r9 = [0.342876]
r10 = [0.148006]
r11 = [0.065869]
r12 = [0.092832]
r13 = [0.410527]
r14 = [-0.063273]
r15 = [-0.117040]
r16 = [-0.065744]
r17 = [-0.010200]
r18 = [-0.452378]
r19 = [-0.118651]
r20 = [0.375678]
r21 = [-0.165005]
r22 = [-0.159090]
r23 = [-0.012716]
r24 = [0.359086]
r25 = [-0.086352]
r26 = [-0.102117]
r27 = [-0.077042]
r28 = [0.279519]
r29 = [0.041353]
r30 = [-0.122573]
r31 = [-0.197082]
r32 = [0.303066]
r33 = [0.240250]
r34 = [0.133422]
r35 = [-0.336839]
r36 = [-0.250422]
r37 = [0.074018]
r38 = [-0.094753]
r39 = [0.137445]
r40 = [0.189965]
r41 = [-0.176732]
r42 = [0.176511]



l = ["ACCESS1-0"]
l1 = ["ACCESS1-3"]
l2 = ["bcc-csm1-1-m"]
l3 = ["csm1-1"]
l4 = ["BNU-ESM"]
l5 = ["CanESM2"]
l6 = ["CCSM4"]
l7 = ["CESM1-BGC"]
l8 = ["CESM1-CAM5"]
l9 = ["CMCC-CM"]
l10 = ["CMCC-CMS"]
l11 = ["CNRM-CM5"]
l12 = ["CSIRO-Mk3-6-0"]
l13 = ["EC-EARTH"]
l14 = ["FGOALS-g2"]
l15 = ["FIO-ESM"]
l16 = ["GISS-E2-H-CC"]
l17 = ["GISS-E2-H1"]
l18 = ["GISS-E2-H2"]
l19 = ["GISS-E2-H3"]
l20 = ["GISS-E2-R-CC"]
l21 = ["GISS-E2-R1"]
l22 = ["GISS-E2-R2"]
l23 = ["GISS-E2-R3"]
l24 = ["inmcm4"]
l25 = ["IPSL-CM5A-LR"]
l26 = ["IPSL-CM5A-MR"]
l27 = ["IPSL-CM5B-LR"]
l28 = ["MIROC5"]
l29 = ["MIROC-ESM-CHEM"]
l30 = ["MIROC-ESM"]
l31 = ["MPI-ESM-LR"]
l32 = ["MPI-ESM-MR"]
l33 = ["MRI-CGCM3"]
l34 = ["NorESM1-ME"]
l35 = ["NorESM1-M"]
l36 = ["GFDL-CM3"]
l37 = ["GFDL-ESM2G"]
l38 = ["GFDL-ESM2M"]
l39 = ["HadGEM2-AO"]
l40 = ["HadGEM2-CC"]
l41 = ["HadGEM2-ES"]
l42 = ["onemean"]

fname = 'TaylorDiagram.jpg'
srl(obsSTD, s, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30, s31, s32, s33, s34, s35, s36, s37, s38, s39, s40, s41, s42, r, r1, r2, r3, r4, r5, r6, r7, r8, r9, r10, r11, r12, r13, r14, r15, r16, r17, r18, r19, r20, r21, r22, r23, r24, r25, r26, r27, r28, r29, r30, r31, r32, r33, r34, r35, r36, r37, r38, r39, r40, r41, r42, l, l1, l2, l3, l4, l5, l6, l7, l8, l9, l10, l11, l12, l13, l14, l15, l16, l17, l18, l19, l20, l21, l22, l23, l24, l25, l26, l27, l28,l29,l30,l31,l32,l33,l34,l35,l36,l37,l38,l39,l40,l41,l42, fname)
